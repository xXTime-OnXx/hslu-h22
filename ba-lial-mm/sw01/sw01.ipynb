# %%
import numpy as np
import matplotlib.pyplot as pl

# %%
x = [-7, 13, 2]

# %%
y = [-3, -5, 11]

# %%
pl.plot(x, y, 'o', color = 'red')
pl.axis('equal')
pl.grid()

# %%
a = np.array([
    [-7],
    [-3]
])

# %%
def Vec(x, y):
    return np.array([[x],[y]])

# %%
b = Vec(13, -5)

# %%
pl.plot(x, y, 'o', color = 'red')
pl.axis('equal')
pl.arrow(a[0, 0], a[1, 0], b[0, 0] - a[0, 0], b[1, 0] - a[1, 0], head_width = 1)
pl.grid()

# %%
a = Vec(-7, -3)

# %%
b = Vec(13, -5)

# %%
c = Vec(2, 11)

# %%
(a + b) + (b + c)
# Out:
# array([[21],
#        [-2]])

# %%
pl.plot(x, y, 'o', color = 'red')
pl.axis('equal')
pl.arrow(a[0, 0], a[1, 0], b[0, 0] - a[0, 0], b[1, 0] - a[1, 0], head_width = 1)
pl.arrow(a[0, 0], a[1, 0], c[0, 0] - a[0, 0], c[1, 0] - a[1, 0], head_width = 1)
r = (a + b) + (a + c)
print(r)
# pl.arrow(a[0, 0], a[1, 0], r[0, 0] - a[0, 0], r[1, 0] - a[1, 0], head_width = 1)
pl.grid()
# Out:
# [[1]
#  [0]]

# %%
a = 

pl.plot(x, y, 'o', color = 'red')
pl.axis('equal')
pl.arrow(a[0, 0], a[1, 0], b[0, 0] - a[0, 0], b[1, 0] - a[1, 0], head_width = 1)
pl.arrow(a[0, 0], a[1, 0], c[0, 0] - a[0, 0], c[1, 0] - a[1, 0], head_width = 1)
r = (a + b) + (a + c)
print(r)
# pl.arrow(a[0, 0], a[1, 0], r[0, 0] - a[0, 0], r[1, 0] - a[1, 0], head_width = 1)
pl.grid()
